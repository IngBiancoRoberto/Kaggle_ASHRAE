# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from time import time
import datetime as dt
import importlib

import aux_funcs as aux

# %%
test = aux.read_test_data()
# Out:
# test.csv read in 35.0 s
# Mem. usage decreased to 596.49 Mb (53.1% reduction)
# (41697600, 10)
#    row_id  building_id  meter  timestamp  hour  day  year  weeknumber  \
# 0       0            0      0 2017-01-01     0    1  2017          52
# 1       1            1      0 2017-01-01     0    1  2017          52
# 2       2            2      0 2017-01-01     0    1  2017          52
# 3       3            3      0 2017-01-01     0    1  2017          52
# 4       4            4      0 2017-01-01     0    1  2017          52
#
#    weekday  month
# 0        6      1
# 1        6      1
# 2        6      1
# 3        6      1
# 4        6      1

# %%
weather_full_test = aux.read_full_weather_test_data()
# Out:
# Weather_test_fulldata.csv read in 0.3 s
# Mem. usage decreased to  2.94 Mb (54.2% reduction)

# %%
building = aux.read_building_data()
# Out:
# building_metadata.csv read in 0.2 s
# Mem. usage decreased to  0.03 Mb (60.3% reduction)
# (1449, 7)
#    site_id  building_id primary_use  square_feet  year_built  floor_count  \
# 0        0            0   Education         7432      2008.0          NaN
# 1        0            1   Education         2720      2004.0          NaN
# 2        0            2   Education         5376      1991.0          NaN
# 3        0            3   Education        23685      2002.0          NaN
# 4        0            4   Education       116607      1975.0          NaN
#
#    log_square_feet
# 0         8.913550
# 1         7.908387
# 2         8.589700
# 3        10.072597
# 4        11.666565

# %%
building.drop(columns=['year_built','floor_count'],inplace=True)
building.head()
# Out:
#    site_id  building_id primary_use  square_feet  log_square_feet
# 0        0            0   Education         7432         8.913550
# 1        0            1   Education         2720         7.908387
# 2        0            2   Education         5376         8.589700
# 3        0            3   Education        23685        10.072597
# 4        0            4   Education       116607        11.666565

# %% [markdown]
# ### join

# %%
#merge tables
testbw = test.join(building, on='building_id', rsuffix = 'r')
testbw.drop(columns=['building_idr'],inplace=True)
print(testbw.shape)
testbw.head()
# Out:
# (41697600, 14)
#    row_id  building_id  meter  timestamp  hour  day  year  weeknumber  \
# 0       0            0      0 2017-01-01     0    1  2017          52
# 1       1            1      0 2017-01-01     0    1  2017          52
# 2       2            2      0 2017-01-01     0    1  2017          52
# 3       3            3      0 2017-01-01     0    1  2017          52
# 4       4            4      0 2017-01-01     0    1  2017          52
#
#    weekday  month  site_id primary_use  square_feet  log_square_feet
# 0        6      1        0   Education         7432         8.913550
# 1        6      1        0   Education         2720         7.908387
# 2        6      1        0   Education         5376         8.589700
# 3        6      1        0   Education        23685        10.072597
# 4        6      1        0   Education       116607        11.666565

# %%
testbw = pd.merge(testbw, weather_full_test,left_on=['site_id','timestamp'],right_on=['site_id','timestamp'],how='left')
print(testbw.shape)
testbw.head()
# Out:
# (41697600, 15)
#    row_id  building_id  meter  timestamp  hour  day  year  weeknumber  \
# 0       0            0      0 2017-01-01     0    1  2017          52
# 1       1            1      0 2017-01-01     0    1  2017          52
# 2       2            2      0 2017-01-01     0    1  2017          52
# 3       3            3      0 2017-01-01     0    1  2017          52
# 4       4            4      0 2017-01-01     0    1  2017          52
#
#    weekday  month  site_id primary_use  square_feet  log_square_feet  \
# 0        6      1        0   Education         7432         8.913550
# 1        6      1        0   Education         2720         7.908387
# 2        6      1        0   Education         5376         8.589700
# 3        6      1        0   Education        23685        10.072597
# 4        6      1        0   Education       116607        11.666565
#
#    air_temperature
# 0        17.796875
# 1        17.796875
# 2        17.796875
# 3        17.796875
# 4        17.796875

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor

predictor_file = 'adaboost_01.pkl'
# read trees
import pickle
with open(predictor_file,'rb') as file:
    dtrs = pickle.load(file)

# %%
# initialise with nans
testbw['log_meter_reading'] = np.nan

# %%
features_list=['weeknumber','weekday','hour','log_square_feet','air_temperature']

# %%
subgroups = testbw.groupby(['primary_use','meter'])['meter'].count()
subgroups
# Out:
# primary_use                    meter
# Education                      0        9408240
#                                1        3784320
#                                2        2382720
#                                3        1226400
# Entertainment/public assembly  0        3136080
#                                1         770880
#                                2         525600
#                                3         280320
# Food sales and service         0          87600
#                                1          70080
#                                2          35040
#                                3          35040
# Healthcare                     0         367920
#                                1         227760
#                                2         157680
#                                3          52560
# Lodging/residential            0        2540400
#                                1         981120
#                                2         788400
#                                3         192720
# Manufacturing/industrial       0         175200
#                                1          17520
#                                2          70080
# Office                         0        4712880
#                                1        2330160
#                                2        1384080
#                                3         578160
# Other                          0         438000
#                                1          52560
#                                2          17520
# Parking                        0         385440
#                                1          17520
#                                2          35040
# Public services                0        2715600
#                                1         367920
#                                2         175200
#                                3         157680
# Religious worship              0          52560
#                                1          17520
# Retail                         0         192720
#                                1          35040
# Services                       0         157680
#                                2          35040
# Technology/science             0         105120
#                                1          35040
#                                2          17520
#                                3          17520
# Utility                        0          70080
#                                1          17520
#                                2          35040
# Warehouse/storage              0         210240
#                                2          17520
# Name: meter, dtype: int64

# %%
def section_predict(dtr, testbw, cond, features_list, thr=100000, out_column='log_meter_reading',verbose=0):
    # breaks down prediction
    #
    # dtr, regression model
    # testbw, dataframe with data
    # cond, vectors of booleans
    # features_list, features to be used for predict
    # thr, threshold where to break down prediction

    #indices where cond is true
    print('Extracting sub-dataframe...')
    ixcond = testbw.loc[cond].index
    
    if len(ixcond) < thr:
        # if below threshold, do it all at once
        testbw.loc[cond,out_column] =\
            dtr.predict(testbw.loc[cond, features_list])
    else:
        # bin definition
        bins = np.arange(0,len(ixcond),thr)
        print('Predicting with {:d} sections'.format(len(bins)))
        
        # loop
        for k in range(len(bins)-1):
            low = bins[k]
            high = bins[k+1]
            if verbose>0:
                print('Section {:d} out of {:d}'.format(k, len(bins)))
            # predict
            testbw.loc[ixcond[low:high],out_column] = dtr.predict(testbw.loc[ixcond[low:high], features_list])
                      
        # last bit
        ixend = bins[-1]
        testbw.loc[ixcond[ixend:],out_column] =\
            dtr.predict(testbw.loc[ixcond[ixend:], features_list])
                      
    return testbw

# %%
# delete vars to free memory (hopefully)
del weather_full_test
del building
del test

# %%
subix = subgroups.index
## CHANGE INDEX TO 0 IN RANGE!!!!!
for k in range(0, len(subgroups)):

    use = subix[k][0]
    meter = subix[k][1]
    dtr = dtrs[k]
    
    print('----------------')
    print(k, use, meter)
    print('   Filter by use and meter...')
    # condition
    cond = (testbw['primary_use']== use) & (testbw['meter']==meter)
    # predict
    t0 = time()
    print('   Predict...')
    testbw = section_predict(dtr, testbw, cond, features_list, verbose=1)
    print('   Prediction in {:.1f}'.format(time()-t0))
    print('   Done!')
    print('')
# Out:
# ----------------
# 0 Education 0
#    Filter by use and meter...
#    Predict...
# Extracting sub-dataframe...
# Predicting with 95 sections
# Section 0 out of 95
# Section 1 out of 95
# Section 2 out of 95
# Section 3 out of 95
# Section 4 out of 95
# Section 5 out of 95
# Section 6 out of 95
# Section 7 out of 95
# Section 8 out of 95
# Section 9 out of 95
# Section 10 out of 95
# Section 11 out of 95
# Section 12 out of 95
# Section 13 out of 95
# Section 14 out of 95
# Section 15 out of 95
# Section 16 out of 95
# Section 17 out of 95
# Section 18 out of 95
# Section 19 out of 95
# Section 20 out of 95
# Section 21 out of 95
# Section 22 out of 95
# Section 23 out of 95
# Section 24 out of 95
# Section 25 out of 95
# Section 26 out of 95
# Section 27 out of 95
# Section 28 out of 95
# Section 29 out of 95
# Section 30 out of 95
# Section 31 out of 95
# Section 32 out of 95
# Section 33 out of 95
# Section 34 out of 95
# Section 35 out of 95
# Section 36 out of 95
# Section 37 out of 95
# Section 38 out of 95
# Section 39 out of 95
# Section 40 out of 95
# Section 41 out of 95
# Section 42 out of 95
# Section 43 out of 95
# Section 44 out of 95
# Section 45 out of 95
# Section 46 out of 95
# Section 47 out of 95
# Section 48 out of 95
# Section 49 out of 95
# Section 50 out of 95
# Section 51 out of 95
# Section 52 out of 95
# Section 53 out of 95
# Section 54 out of 95
# Section 55 out of 95
# Section 56 out of 95
# Section 57 out of 95
# Section 58 out of 95
# Section 59 out of 95
# Section 60 out of 95
# Section 61 out of 95
# Section 62 out of 95
# Section 63 out of 95
# Section 64 out of 95
# Section 65 out of 95
# Section 66 out of 95
# Section 67 out of 95
# Section 68 out of 95
# Section 69 out of 95
# Section 70 out of 95
# Section 71 out of 95
# Section 72 out of 95
# Section 73 out of 95
# Section 74 out of 95
# Section 75 out of 95
# Section 76 out of 95
# Section 77 out of 95
# Section 78 out of 95
# Section 79 out of 95
# Section 80 out of 95
# Section 81 out of 95
# Section 82 out of 95
# Section 83 out of 95
# Section 84 out of 95
# Section 85 out of 95
# Section 86 out of 95
# Section 87 out of 95
# Section 88 out of 95
# Section 89 out of 95
# Section 90 out of 95
# Section 91 out of 95
# Section 92 out of 95
# Section 93 out of 95
#    Prediction in 321.2
#    Done!
#
# ----------------
# 1 Education 1
#    Filter by use and meter...
#    Predict...
# Extracting sub-dataframe...
# Predicting with 38 sections
# Section 0 out of 38
# Section 1 out of 38
# Section 2 out of 38
# Section 3 out of 38
# Section 4 out of 38
# Section 5 out of 38
# Section 6 out of 38
# Section 7 out of 38
# Section 8 out of 38
# Section 9 out of 38
# Section 10 out of 38
# Section 11 out of 38
# Section 12 out of 38
# Section 13 out of 38
# Section 14 out of 38
# Section 15 out of 38
# Section 16 out of 38
# Section 17 out of 38
# Section 18 out of 38
# Section 19 out of 38
# Section 20 out of 38
# Section 21 out of 38
# Section 22 out of 38
# Section 23 out of 38
# Section 24 out of 38
# Section 25 out of 38
# Section 26 out of 38
# Section 27 out of 38
# Section 28 out of 38
# Section 29 out of 38
# Section 30 out of 38
# Section 31 out of 38
# Section 32 out of 38
# Section 33 out of 38
# Section 34 out of 38
# Section 35 out of 38
# Section 36 out of 38
#    Prediction in 78.9
#    Done!
#
# ----------------
# 2 Education 2
#    Filter by use and meter...
#    Predict...
# Extracting sub-dataframe...
# Predicting with 24 sections
# Section 0 out of 24
# Section 1 out of 24
# Section 2 out of 24
# Section 3 out of 24
# Section 4 out of 24
# Section 5 out of 24
# Section 6 out of 24
# Section 7 out of 24
# Section 8 out of 24
# Section 9 out of 24
# Section 10 out of 24
# Section 11 out of 24
# Section 12 out of 24
# Section 13 out of 24
# Section 14 out of 24
# Section 15 out of 24
# Section 16 out of 24
# Section 17 out of 24
# Section 18 out of 24
# Section 19 out of 24
# Section 20 out of 24
# Section 21 out of 24
# Section 22 out of 24
#    Prediction in 51.5
#    Done!
#
# ----------------
# 3 Education 3
#    Filter by use and meter...
#    Predict...
# Extracting sub-dataframe...
# Predicting with 13 sections
# Section 0 out of 13
# Section 1 out of 13
# Section 2 out of 13
# Section 3 out of 13
# Section 4 out of 13
# Section 5 out of 13
# Section 6 out of 13
# Section 7 out of 13
# Section 8 out of 13
# Section 9 out of 13
# Section 10 out of 13
# Section 11 out of 13
#    Prediction in 34.3
#    Done!
#
# ----------------
# 4 Entertainment/public assembly 0
#    Filter by use and meter...
#    Predict...
# Extracting sub-dataframe...
# Predicting with 32 sections
# Section 0 out of 32
# Section 1 out of 32
# Section 2 out of 32
# Section 3 out of 32
# Section 4 out of 32
# Section 5 out of 32
# Section 6 out of 32
# Section 7 out of 32
# Section 8 out of 32
# Section 9 out of 32
# Section 10 out of 32
# Section 11 out of 32
# Section 12 out of 32
# Section 13 out of 32
# Section 14 out of 32
# Section 15 out of 32
# Section 16 out of 32
# Section 17 out of 32
# Section 18 out of 32
# Section 19 out of 32
# Section 20 out of 32
# Section 21 out of 32
# Section 22 out of 32
# Section 23 out of 32
# Section 24 out of 32
# Section 25 out of 32
# Section 26 out of 32
# Section 27 out of 32
# Section 28 out of 32
# Section 29 out of 32
# Section 30 out of 32
#    Prediction in 155.4
#    Done!
#
# ----------------
# 5 Entertainment/public assembly 1
#    Filter by use and meter...
#    Predict...
# Extracting sub-dataframe...
# Predicting with 8 sections
# Section 0 out of 8
# Section 1 out of 8
# Section 2 out of 8
# Section 3 out of 8
# Section 4 out of 8
# Section 5 out of 8
# Section 6 out of 8
#    Prediction in 23.4
#    Done!
#
# ----------------
# 6 Entertainment/public assembly 2
#    Filter by use and meter...
#    Predict...
# Extracting sub-dataframe...
# Predicting with 6 sections
# Section 0 out of 6
# Section 1 out of 6
# Section 2 out of 6
# Section 3 out of 6
# Section 4 out of 6
#    Prediction in 16.2
#    Done!
#
# ----------------
# 7 Entertainment/public assembly 3
#    Filter by use and meter...
#    Predict...
# Extracting sub-dataframe...
# Predicting with 3 sections
# Section 0 out of 3
# Section 1 out of 3
#    Prediction in 10.9
#    Done!
#
# ----------------
# 8 Food sales and service 0
#    Filter by use and meter...
#    Predict...
# Extracting sub-dataframe...
#    Prediction in 5.9
#    Done!
#
# ----------------
# 9 Food sales and service 1
#    Filter by use and meter...
#    Predict...
# Extracting sub-dataframe...
#    Prediction in 3.1
#    Done!
#
# ----------------
# 10 Food sales and service 2
#    Filter by use and meter...
#    Predict...
# Extracting sub-dataframe...
#    Prediction in 2.7
#    Done!
#
# ----------------
# 11 Food sales and service 3
#    Filter by use and meter...
#    Predict...
# Extracting sub-dataframe...
#    Prediction in 1.3
#    Done!
#
# ----------------
# 12 Healthcare 0
#    Filter by use and meter...
#    Predict...
# Extracting sub-dataframe...
# Predicting with 4 sections
# Section 0 out of 4
# Section 1 out of 4
# Section 2 out of 4
#    Prediction in 14.4
#    Done!
#
# ----------------
# 13 Healthcare 1
#    Filter by use and meter...
#    Predict...
# Extracting sub-dataframe...
# Predicting with 3 sections
# Section 0 out of 3
# Section 1 out of 3
#    Prediction in 9.1
#    Done!
#
# ----------------
# 14 Healthcare 2
#    Filter by use and meter...
#    Predict...
# Extracting sub-dataframe...
# Predicting with 2 sections
# Section 0 out of 2
#    Prediction in 4.9
#    Done!
#
# ----------------
# 15 Healthcare 3
#    Filter by use and meter...
#    Predict...
# Extracting sub-dataframe...
#    Prediction in 2.2
#    Done!
#
# ----------------
# 16 Lodging/residential 0
#    Filter by use and meter...
#    Predict...
# Extracting sub-dataframe...
# Predicting with 26 sections
# Section 0 out of 26
# Section 1 out of 26
# Section 2 out of 26
# Section 3 out of 26
# Section 4 out of 26
# Section 5 out of 26
# Section 6 out of 26
# Section 7 out of 26
# Section 8 out of 26
# Section 9 out of 26
# Section 10 out of 26
# Section 11 out of 26
# Section 12 out of 26
# Section 13 out of 26
# Section 14 out of 26
# Section 15 out of 26
# Section 16 out of 26
# Section 17 out of 26
# Section 18 out of 26
# Section 19 out of 26
# Section 20 out of 26
# Section 21 out of 26
# Section 22 out of 26
# Section 23 out of 26
# Section 24 out of 26
#    Prediction in 52.1
#    Done!
#
# ----------------
# 17 Lodging/residential 1
#    Filter by use and meter...
#    Predict...
# Extracting sub-dataframe...
# Predicting with 10 sections
# Section 0 out of 10
# Section 1 out of 10
# Section 2 out of 10
# Section 3 out of 10
# Section 4 out of 10
# Section 5 out of 10
# Section 6 out of 10
# Section 7 out of 10
# Section 8 out of 10
#    Prediction in 20.3
#    Done!
#
# ----------------
# 18 Lodging/residential 2
#    Filter by use and meter...
#    Predict...
# Extracting sub-dataframe...
# Predicting with 8 sections
# Section 0 out of 8
# Section 1 out of 8
# Section 2 out of 8
# Section 3 out of 8
# Section 4 out of 8
# Section 5 out of 8
# Section 6 out of 8
#    Prediction in 22.9
#    Done!
#
# ----------------
# 19 Lodging/residential 3
#    Filter by use and meter...
#    Predict...
# Extracting sub-dataframe...
# Predicting with 2 sections
# Section 0 out of 2
#    Prediction in 5.7
#    Done!
#
# ----------------
# 20 Manufacturing/industrial 0
#    Filter by use and meter...
#    Predict...
# Extracting sub-dataframe...
# Predicting with 2 sections
# Section 0 out of 2
#    Prediction in 7.0
#    Done!
#
# ----------------
# 21 Manufacturing/industrial 1
#    Filter by use and meter...
#    Predict...
# Extracting sub-dataframe...
#    Prediction in 2.2
#    Done!
#
# ----------------
# 22 Manufacturing/industrial 2
#    Filter by use and meter...
#    Predict...
# Extracting sub-dataframe...
#    Prediction in 1.5
#    Done!
#
# ----------------
# 23 Office 0
#    Filter by use and meter...
#    Predict...
# Extracting sub-dataframe...
# Predicting with 48 sections
# Section 0 out of 48
# Section 1 out of 48
# Section 2 out of 48
# Section 3 out of 48
# Section 4 out of 48
# Section 5 out of 48
# Section 6 out of 48
# Section 7 out of 48
# Section 8 out of 48
# Section 9 out of 48
# Section 10 out of 48
# Section 11 out of 48
# Section 12 out of 48
# Section 13 out of 48
# Section 14 out of 48
# Section 15 out of 48
# Section 16 out of 48
# Section 17 out of 48
# Section 18 out of 48
# Section 19 out of 48
# Section 20 out of 48
# Section 21 out of 48
# Section 22 out of 48
# Section 23 out of 48
# Section 24 out of 48
# Section 25 out of 48
# Section 26 out of 48
# Section 27 out of 48
# Section 28 out of 48
# Section 29 out of 48
# Section 30 out of 48
# Section 31 out of 48
# Section 32 out of 48
# Section 33 out of 48
# Section 34 out of 48
# Section 35 out of 48
# Section 36 out of 48
# Section 37 out of 48
# Section 38 out of 48
# Section 39 out of 48
# Section 40 out of 48
# Section 41 out of 48
# Section 42 out of 48
# Section 43 out of 48
# Section 44 out of 48
# Section 45 out of 48
# Section 46 out of 48
#    Prediction in 125.7
#    Done!
#
# ----------------
# 24 Office 1
#    Filter by use and meter...
#    Predict...
# Extracting sub-dataframe...
# Predicting with 24 sections
# Section 0 out of 24

# %%
# convert from log to linear
testbw['meter_reading'] = np.exp(testbw['log_meter_reading'])-1

# %%
testbw.head()

# %%
#export results
filename = 'submission_03_191028.csv'
# 
testbw.loc[:,['row_id','meter_reading']].to_csv(filename,index=False)

# %%
aux.get_lines(filename)
